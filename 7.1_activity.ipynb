# %% [markdown]
# Matplotib activity.

# %%
from matplotlib import pylab
print(pylab.__version__)
# Out:
# 1.19.1

# %%
import numpy as np

x = np.linspace(0,10,25)
y = x*x+2
print(x)
print(y)
print(np.array([x,y]).reshape(25,2))
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]
# [[  0.           0.41666667]
#  [  0.83333333   1.25      ]
#  [  1.66666667   2.08333333]
#  [  2.5          2.91666667]
#  [  3.33333333   3.75      ]
#  [  4.16666667   4.58333333]
#  [  5.           5.41666667]
#  [  5.83333333   6.25      ]
#  [  6.66666667   7.08333333]
#  [  7.5          7.91666667]
#  [  8.33333333   8.75      ]
#  [  9.16666667   9.58333333]
#  [ 10.           2.        ]
#  [  2.17361111   2.69444444]
#  [  3.5625       4.77777778]
#  [  6.34027778   8.25      ]
#  [ 10.50694444  13.11111111]
#  [ 16.0625      19.36111111]
#  [ 23.00694444  27.        ]
#  [ 31.34027778  36.02777778]
#  [ 41.0625      46.44444444]
#  [ 52.17361111  58.25      ]
#  [ 64.67361111  71.44444444]
#  [ 78.5625      86.02777778]
#  [ 93.84027778 102.        ]]

# %%
pylab.plot(x,y, 'r') #r means red

# %%
#subgraphs

pylab.subplot(1,2,1)
pylab.plot(x,y, 'r--') #row one coloumn two
pylab.subplot(1,2,2)
pylab.plot(y, x, 'g*-') #row two coloumn two

# %%
pylab.subplot(1,2,1)
pylab.plot(x,y, 'r--') #row one coloumn two
pylab.subplot(1,2,1)
pylab.plot(y, x, 'g*-') #row two coloumn two
# Out:
# /home/sandrews/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
pylab.subplot(1,2,1)
pylab.plot(x,y, 'r--') #row one coloumn two
pylab.subplot(2,2,2)
pylab.plot(y, x, 'g*-') #row two coloumn two

# %%
from matplotlib import pyplot as plt

# %%
fig = plt.figure()

axis = fig.add_axes([0.5,0.1,0.8,0.8])

axis.plot(x,y, 'r')

# %%
#draw subgraphs
fig, axes = plt.subplots(nrows = 1, ncols = 3)
for ax in axes:
    ax.plot(x,y, 'r')

# %%
#we can also draw a pciture or graph inside another graph

fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) #big axes
axes2 = fig.add_axes([0.2,0.6,0.2,0.2]) #small canvas

axes1.plot(x,y, 'r')
axes2.plot(y,x, 'g')

# %%
fig = plt.figure(figsize = (16,9), dpi = 100)

fig.add_subplot()

plt.plot(x,y, 'r')

# %%
fig, axes = plt.subplots(figsize=(16,9), dpi=50)
axes.plot(x,y,'r')

# %%
ax.legend(["label1", "label2"])

fig, axes = plt.subplots()
axes.set_xlabel("x label")
axes.set_ylabel('y label')
axes.set_title("title of graph")

axes.plot(x,y,'r')

axes.legend(["y = x**2", "y = x**3"], loc=2)

# %%
ax.legend(["label1", "label2"])

fig, axes = plt.subplots()
axes.set_xlabel("x label")
axes.set_ylabel('y label')
axes.set_title("title of graph")

axes.plot(x, x**2)
axes.plot(x, x**3)

axes.legend(["y = x**2", "y = x**3"], loc=2)

# %%
ax.legend(["label1", "label2"])

fig, axes = plt.subplots(dpi=200)
axes.set_xlabel("x label")
axes.set_ylabel('y label')
axes.set_title("title of graph")

axes.plot(x, x**2)
axes.plot(x, x**3)

axes.legend(["y = x**2", "y = x**3"], loc=2)

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1, color =  'red', alpha=.5)
axes.plot(x, x+2, color = '#1155dd')
axes.plot(x, x+3, color = 'green')

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x**2, color =  'red', alpha=.3)
axes.plot(x, x+2, color = '#1155dd', alpha =.8)
axes.plot(x, x+3, color = 'green', alpha=.8)

# %%
fig, ax = plt.subplots(dpi=100)

ax.plot(x, x+1, color = 'blue', linewidth=0.25)
ax.plot(x, x+2, color = 'blue', linewidth=1)
ax.plot(x, x+3, color = 'blue', linewidth=1.5)
ax.plot(x, x+4, color = 'blue', linewidth=2)

# %%
fig, ax = plt.subplots(dpi=100)

ax.plot(x, x+1, color = 'blue', lw=2, linestyle='-')
ax.plot(x, x+2, color = 'blue', lw=2, linestyle = '-.')
ax.plot(x, x+3, color = 'blue', lw=2, linestyle = ':')

line, = ax.plot(x, x+4, color='black', lw=1.5)
line.set_dashes([5,10,15,10])

line, = ax.plot(x, x+5, color='black', lw=1.5)
line.set_dashes([5,10,15,3])

line, = ax.plot(x, x+6, color='black', lw=1.5)
line.set_dashes([5,10,30,30])

# %%
fig, ax = plt.subplots(dpi=100)

ax.plot(x, x+1, color = 'blue', marker = 'o')
ax.plot(x, x+2, color = 'blue', marker = '+')
ax.plot(x, x+3, color = 'blue', marker='s')
ax.plot(x, x+4, color = 'blue', marker='1')

ax.plot(x, x+5, color = 'blue', marker = 'o', markersize=5)
ax.plot(x, x+6, color = 'blue', marker = 's', markerfacecolor='red')
ax.plot(x, x+7, color = 'blue', marker = 'o', markersize=8, markerfacecolor="green")

# %%
fig, Axes = plt.subplots(1,2, figsize=(10,5))

Axes[0].plot(x, x**2, x, x**3, lw=2)
Axes[0].grid(True)

Axes[1].plot(x, x**2, x, x**3, lw=2)
Axes[1].grid(True)
Axes[1].set_ylim([0,60])
Axes[1].set_xlim([2,5])
# Out:
# (2, 5)

# %% [markdown]
# #other 2d graphs

# %%
n = np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1,4,figsize=(16,5))
axes[0].set_title('scatter plot')
axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))

axes[1].set_title('step plot')
axes[1].step(n, n**2, lw=2 )

axes[2].set_title('bar')
axes[2].bar(n, n**2, align='center', width=0.5, alpha=0.5)

axes[3].set_title('bar')
axes[3].fill_between(x, x**2, x**3, color = 'green', alpha=0.5)

# %%
#radar chart

fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0,0.0,0.6,0.6], polar=True)
t = np.linspace(0,2*np.pi, 100)
ax.plot(t,t, color='blue', lw=3)

# %%
#histogram

n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12,4))
axes[0].set_title("Defualt histogram")
axes[0].hist(n)


axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=10)
# Out:
# (array([7.4000e+01, 9.9900e+02, 7.2040e+03, 2.7376e+04, 6.0459e+04,
#         8.7072e+04, 9.7753e+04, 9.9810e+04, 9.9993e+04, 1.0000e+05]),
#  array([-4.07093583, -3.2026439 , -2.33435197, -1.46606003, -0.5977681 ,
#          0.27052383,  1.13881576,  2.0071077 ,  2.87539963,  3.74369156,
#          4.61198349]),
#  <a list of 10 Patch objects>)

# %%
#contour map

import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y-1)**2)
Z = (Z1 - Z2) * 2

print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
fig, ax = plt.subplots()
CS = ax.contour(X,Y,Z)
ax.clabel(CS, inline=1, fontsize=10)
ax.set_title('contour map')
# Out:
# Text(0.5,1,'contour map')

# %%
#Draw a 3d Surface

from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14,6))

ax = fig.add_subplot(1,1,1,projection='3d')

ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# %%
#heatmap or color map

# %% [markdown]
# practice example:
#
# Write a python programming to create a pie chart of the popularity of programming languages

# %%
import matplotlib.pyplot as plt
#data to plot
languages = 'Python', 'Java', 'PHP', 'JavaScript', 'C#', "C++"
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b"]

# %%
#explode 1st slice

explode = (0.1,0,0,0,0,0)
plt.pie(popularity, explode=explode, labels=languages, colors=colors,
autopct = '%1.1f%%', shadow=True, startangle=0)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8b24ebf470>,
#   <matplotlib.patches.Wedge at 0x7f8b24ebff28>,
#   <matplotlib.patches.Wedge at 0x7f8b24ec19e8>,
#   <matplotlib.patches.Wedge at 0x7f8b24ec34a8>,
#   <matplotlib.patches.Wedge at 0x7f8b24ec3ef0>,
#   <matplotlib.patches.Wedge at 0x7f8b24ec59b0>],
#  [Text(0.666132,0.998132,'Python'),
#   Text(-1.01392,0.426566,'Java'),
#   Text(-0.789769,-0.765679,'PHP'),
#   Text(-0.0632393,-1.09818,'JavaScript'),
#   Text(0.654414,-0.884162,'C#'),
#   Text(1.05201,-0.32135,'C++')],
#  [Text(0.388577,0.582244,'31.3%'),
#   Text(-0.553049,0.232672,'24.8%'),
#   Text(-0.430783,-0.417643,'12.4%'),
#   Text(-0.0344942,-0.599008,'11.3%'),
#   Text(0.356953,-0.48227,'10.8%'),
#   Text(0.573826,-0.175282,'9.4%')])
